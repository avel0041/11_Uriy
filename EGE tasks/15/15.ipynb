# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# def f(x, a):
#     return (a%9==0) and (280%x==0) <= ( (not(a%x==0))<=(not(730%x==0)) )

# n = 0

# for a in range(1, 1001):
#     fl=0
#     for x in range(1, 10000):
#         if not f(x, a):
#             fl=1
#             break
#     if fl == 0:
#         n+=1
# print(n)

# def f(x, y, a):
#     return (x-2*y<3*a) or (2*y>x) or (3*x>50)

# for a in range(1, 1000):
#     fl = 0
#     for x in range(1, 1000):
#         if fl == 1:
#                 break
#         for y in range(1, 1000):
#             if not f(x, y, a):
#                 fl = 1
#                 break
#     if fl == 0:
#         print(a)
#         break

# def f(x, a):
#     return x&51 == 0 or ((x&41 == 0) <= (x&a == 0))

# for a in range(1000, 1, -1):
#     fl = 0
#     for x in range(1, 1000):
#         if not f(x, a):
#             fl = 1
#             break
#     if fl == 0:
#         print(a)
#         break

# p = [x for x in range(10,30)]
# q = [x for x in range(13,19)]
# a = [x for x in range(10,30)]
# for x in range(1,100):
#     if not(((x in a) <= (x in p)) or (x in q)):
#         a.remove(x)
# print(a)

# P = [i for i in range(25, 51)]
# Q = [i for i in range(32, 48)]
# m = 0
# for Amin in range(0, 60):
#     for Amax in range(Amin + 1, 60):
#         check = 1
#         A = [i for i in range(Amin, Amax)]
#         for x in range(0, 101):
#             f = ((not(x in A)) <= (x in P)) <= ((x in A) <= (x in Q))
#             if not f:
#                 check = 0
#                 break
#         if check == 1:
#             m = max(m,Amax - Amin)
# print(m - 1)

# %% [markdown]
# ![image.png](attachment:0e83b252-fe19-43eb-be1b-51a189c57aa8.png)

# %%
# a = []
# for x in range(1, 814625//3+1):
#     y = (814625-3*x)/4
#     if int(y) == y and y>= x - 1222 and (814625-3*x)%4==0:
#         a.append(y)
# print(min(a)-1)

def f(x, y):
    return (3*x+4*y<814625) or (y<x-1222) or (y>a)


p=[]
for a in range(115850, 116000):
    if all(f(x, (814625-3*x)/4) for x in range (1, 300000) if (814625-3*x)%4==0):
        p.append(a)
print(max(p))

# %% [markdown]
# ![image.png](attachment:c720d798-64d3-47ea-9753-c14f8a49de1b.png)

# %%
def f(x, a):
    return (a%5 == 0) and ( (not(2020%a == 0))<=((x%1718 == 0)<=(2023%a == 0)))

k = 0

for a in range(1, 100000):
    if all(f(x, a) for x in range(1, 100000)):
        k+=1
print(k)

# %% [markdown]
# ![image.png](attachment:53d8b314-9b70-44f5-8b0c-33b3fcbb83bb.png)

# %%
f = 1241651 / 6 
s = 413184 / 3
print(f, s)
print(1241651 - 5*206942)
x = 206941   x=206942
y = 206946   y=206941   A = 206942

x = y = 137728          A = 137729

# 10=x+y

# x=y=5

# (A>x)+(A>y)=1
# A = 6

# %% [markdown]
# ![image.png](attachment:0fea9ccf-ac8a-472d-965a-a9dedf1a277e.png)

# %%
print(680*3702+256*1+1)
#2517617

# %% [markdown]
# ![image.png](attachment:eb0e06c7-9ec8-44d0-9557-d77386e9587e.png)

# %%
#15 (аналитически решил)
def f(x, y):
    return ( y + 2*x != 48) or (a < x) or (a < y)
for a in range(1, 1000):
    if all(f(x, y) for x in range(1, 1000) for y in range(1, 1000)):
        print(a)
# Тут легко кодом можно, потому что маленькие числа, но попробуй сначала аналитически

# %% [markdown]
# ![image.png](attachment:12ff1a67-5b58-441e-a54a-da6e16846980.png)

# %%
#122 (аналитически)

def f(x, y):
    return (x * y < a) or (x < y) or (x >= 12)
for a in range(1, 500):
    if all(f(x, y) for x in range(1, 500) for y in range(1, 500)):
        print(a)
        break

# Тут легко кодом можно, потому что маленькие числа, но попробуй сначала аналитически

# %% [markdown]
# ![image.png](attachment:c6bb2780-fff9-4699-852d-2d154c00952d.png)

# %%
#37 (аналитически) с кодом ответ расходится почему-то

def f(x, y):
    return (x > a) or (y > x) or (2*y + x < 110)

for a in range(1, 100):
    if all(f(x, y) for x in range(1, 500) for y in range(1, 500)):
        print(a)
# Тут легко кодом можно, потому что маленькие числа, но попробуй сначала аналитически

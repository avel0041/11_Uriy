# %% [markdown]
# ![image.png](attachment:745b4da7-4a3c-4ffe-8aa0-e4cc7249910a.png)

# %%
f = 03_2206

# %% [markdown]
# ![image.png](attachment:90f3a84b-5efb-4250-8efb-836d6c34285e.png)

# %%
f = 03_22072

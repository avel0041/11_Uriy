# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 19

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 296

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 16

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 1496

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 220

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 1027

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 109

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 15432099
# 248456789

# %% [markdown]
# ![image.png](attachment:2b37e476-e766-4dae-9ccc-4f65d3bae588.png)

# %%
# Out:
# 21

# %% [markdown]
# ![image.png](attachment:c720d798-64d3-47ea-9753-c14f8a49de1b.png)

# %%
def f(x, a):
    return (a%5 == 0) and ( (not(2020%a == 0))<=((x%1718 == 0)<=(2023%a == 0)))

k = 0

for a in range(1, 100000):
    if all(f(x, a) for x in range(1, 100000)):
        k+=1
print(k)
# Out:
# 6

# %% [markdown]
# ![image.png](attachment:7c4a4843-6ee5-4710-8e1b-9800b1e508d4.png)

# %%
# f(12345) = 5*(f(1234)) = 5*4*f(123)
# 9**13

# %% [markdown]
# ![image.png](attachment:f9428a6d-8466-4832-ab49-bab2cee6c224.png)

# %% [markdown]
# ![image.png](attachment:d767191e-db3b-45ba-a4bb-f269fb747773.png)

# %%
# def f(a):
#     if a>8 or a == 0: return 0
#     if a == 8: return 1
#     pr = 1
#     for p in str(a):
#         pr*=int(p)
#     return f(sum(map(int, str(a)))) or f(pr)

def g(a, b):
    if a == b:
        return 1
    if a < 10:
        return 0
    return g(a//10+a%10, b) or g((a//10)*(a%10), b)
k = 0
k1=0
for a in range(10, 100):
    # if f(a): k+=1
    if g(a, 8): k1+=1
print(k1)
# Out:
# 34
